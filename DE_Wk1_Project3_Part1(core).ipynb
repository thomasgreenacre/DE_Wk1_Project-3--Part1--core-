# %%
#imports
import pandas as pd
import numpy as np

# %%
#assign data to variables
title_basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
title_akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
title_ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
#read variable to dataframe
basics = pd.read_csv(title_basics_url,sep='\t', low_memory=False)

# %%
#read variable to dataframe
akas = pd.read_csv(title_akas_url,sep='\t', low_memory=False)

# %%
#read variable to dataframe
ratings = pd.read_csv(title_ratings_url,sep='\t', low_memory=False)

# %%
#view basics df
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#view datatypes of basics df
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9191004 entries, 0 to 9191003
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 631.1+ MB

# %%
#replace \n with NaN
basics = basics.replace({'\\N':np.nan})
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9190999  tt9916848  tvEpisode              Episode #3.17
# 9191000  tt9916850  tvEpisode              Episode #3.19
# 9191001  tt9916852  tvEpisode              Episode #3.20
# 9191002  tt9916856      short                   The Wind
# 9191003  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9190999              Episode #3.17       0      2010     NaN            NaN
# 9191000              Episode #3.19       0      2010     NaN            NaN
# 9191001              Episode #3.20       0      2010     NaN            NaN
# 9191002                   The Wind       0      2015     NaN             27
# 9191003  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9190999         Action,Drama,Family
# 9191000         Action,Drama,Family
# 9191001         Action,Drama,Family
# 9191002                       Short
# 9191003  Adventure,Animation,Comedy
#
# [9191004 rows x 9 columns]

# %%
#change basics.startYear data type to float
basics['startYear']  = basics['startYear'].astype('float')

# %%
#view datatypes of basics df to confirm startYear changed to float
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9191004 entries, 0 to 9191003
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       float64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: float64(1), object(8)
# memory usage: 631.1+ MB

# %%
basics['startYear'] = basics.startYear.round().astype('Int64')

# %%
#view datatypes of basics df to confirm startYear changed to float
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9191004 entries, 0 to 9191003
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       Int64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: Int64(1), object(8)
# memory usage: 639.9+ MB

# %%
#use value_counts to view unique values for startYear
basics.value_counts('startYear')
# Out:
# startYear
# 2021    426182
# 2018    420696
# 2017    417656
# 2019    408211
# 2016    396600
#          ...
# 1881         2
# 1878         2
# 1885         1
# 1883         1
# 1874         1
# Length: 150, dtype: int64

# %%
#run value_counts on titleType to see spelling of values 
basics.value_counts('titleType')
# Out:
# titleType
# tvEpisode       6926196
# short            886801
# movie            619992
# video            264699
# tvSeries         230302
# tvMovie          137348
# tvMiniSeries      44918
# tvSpecial         38102
# videoGame         31998
# tvShort           10646
# tvPilot               2
# dtype: int64

# %%
#replace \n with NaN
akas = akas.replace({'\\N':np.nan})
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
#replace \n with NaN
ratings = ratings.replace({'\\N':np.nan})
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1907
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1707
# 3  tt0000004            5.6       168
# 4  tt0000005            6.2      2520

# %%
basics = basics.dropna(subset=['runtimeMinutes', 'genres'])

# %%
#filter basics df where 'titleType'' equals 'movie'
basics = basics[basics['titleType'] == 'movie'] 
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# 1172     tt0001184     movie
# ...            ...       ...
# 9190769  tt9916362     movie
# 9190853  tt9916538     movie
# 9190894  tt9916622     movie
# 9190921  tt9916680     movie
# 9190954  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# 1172                               Don Juan de Serrallonga
# ...                                                    ...
# 9190769                                              Coven
# 9190853                                Kuambil Lagi Hatiku
# 9190894        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9190921  De la ilusión al desconcierto: cine colombiano...
# 9190954                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 8                                               Miss Jerry       0       1894
# 570                            The Story of the Kelly Gang       0       1906
# 587                                      L'enfant prodigue       0       1907
# 672                         The Fairylogue and Radio-Plays       0       1908
# 1172                               Don Juan de Serrallonga       0       1910
# ...                                                    ...     ...        ...
# 9190769                                           Akelarre       0       2020
# 9190853                                Kuambil Lagi Hatiku       0       2019
# 9190894        Rodolpho Teóphilo - O Legado de um Pioneiro       0       2015
# 9190921  De la ilusión al desconcierto: cine colombiano...       0       2007
# 9190954                     Chico Albuquerque - Revelações       0       2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# 1172        NaN             58             Adventure,Drama
# ...         ...            ...                         ...
# 9190769     NaN             92               Drama,History
# 9190853     NaN            123                       Drama
# 9190894     NaN             57                 Documentary
# 9190921     NaN            100                 Documentary
# 9190954     NaN             49                 Documentary
#
# [367222 rows x 9 columns]

# %%
#filter basics where startYear equals 2000 or 2001
basics = basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]
basics
# Out:
#             tconst titleType  \
# 13079    tt0013274     movie
# 34791    tt0035423     movie
# 61091    tt0062336     movie
# 66306    tt0067683     movie
# 67637    tt0069049     movie
# ...            ...       ...
# 9190769  tt9916362     movie
# 9190853  tt9916538     movie
# 9190894  tt9916622     movie
# 9190921  tt9916680     movie
# 9190954  tt9916754     movie
#
#                                               primaryTitle  \
# 13079                          Istoriya grazhdanskoy voyny
# 34791                                       Kate & Leopold
# 61091    The Tango of the Widower and Its Distorting Mi...
# 66306             Workers '71: Nothing About Us Without Us
# 67637                           The Other Side of the Wind
# ...                                                    ...
# 9190769                                              Coven
# 9190853                                Kuambil Lagi Hatiku
# 9190894        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9190921  De la ilusión al desconcierto: cine colombiano...
# 9190954                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13079                          Istoriya grazhdanskoy voyny       0       2021
# 34791                                       Kate & Leopold       0       2001
# 61091            El Tango del Viudo y Su Espejo Deformante       0       2020
# 66306                   Robotnicy 1971 - Nic o nas bez nas       0       2006
# 67637                           The Other Side of the Wind       0       2018
# ...                                                    ...     ...        ...
# 9190769                                           Akelarre       0       2020
# 9190853                                Kuambil Lagi Hatiku       0       2019
# 9190894        Rodolpho Teóphilo - O Legado de um Pioneiro       0       2015
# 9190921  De la ilusión al desconcierto: cine colombiano...       0       2007
# 9190954                     Chico Albuquerque - Revelações       0       2013
#
#         endYear runtimeMinutes                  genres
# 13079       NaN            133             Documentary
# 34791       NaN            118  Comedy,Fantasy,Romance
# 61091       NaN             70                   Drama
# 66306       NaN             47             Documentary
# 67637       NaN            122                   Drama
# ...         ...            ...                     ...
# 9190769     NaN             92           Drama,History
# 9190853     NaN            123                   Drama
# 9190894     NaN             57             Documentary
# 9190921     NaN            100             Documentary
# 9190954     NaN             49             Documentary
#
# [207486 rows x 9 columns]

# %%
#use value_counts funtion to view unique naming conventions to determine US
akas.value_counts('region')
# Out:
# region
# FR    3944926
# JP    3944914
# DE    3928041
# IN    3873295
# ES    3867982
#        ...
# NU          1
# TV          1
# CC          1
# PW          1
# TC          1
# Length: 247, dtype: int64

# %%
#filter akas to region eques US only
akas = akas[akas['region'] == 'US'] 
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
#filter basics df where genre contains "Documentary"
basics = basics[basics['genres'].str.contains("Documentary")!=True]
basics
# Out:
#             tconst titleType  \
# 34791    tt0035423     movie
# 61091    tt0062336     movie
# 67637    tt0069049     movie
# 77931    tt0079644     movie
# 86768    tt0088751     movie
# ...            ...       ...
# 9190676  tt9916170     movie
# 9190685  tt9916190     movie
# 9190724  tt9916270     movie
# 9190769  tt9916362     movie
# 9190853  tt9916538     movie
#
#                                               primaryTitle  \
# 34791                                       Kate & Leopold
# 61091    The Tango of the Widower and Its Distorting Mi...
# 67637                           The Other Side of the Wind
# 77931                                        November 1828
# 86768                                    The Naked Monster
# ...                                                    ...
# 9190676                                      The Rehearsal
# 9190685                                          Safeguard
# 9190724                           Il talento del calabrone
# 9190769                                              Coven
# 9190853                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34791                               Kate & Leopold       0       2001     NaN
# 61091    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67637                   The Other Side of the Wind       0       2018     NaN
# 77931                                November 1828       0       2001     NaN
# 86768                            The Naked Monster       0       2005     NaN
# ...                                            ...     ...        ...     ...
# 9190676                                   O Ensaio       0       2019     NaN
# 9190685                                  Safeguard       0       2020     NaN
# 9190724                   Il talento del calabrone       0       2020     NaN
# 9190769                                   Akelarre       0       2020     NaN
# 9190853                        Kuambil Lagi Hatiku       0       2019     NaN
#
#         runtimeMinutes                     genres
# 34791              118     Comedy,Fantasy,Romance
# 61091               70                      Drama
# 67637              122                      Drama
# 77931              140                  Drama,War
# 86768              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9190676             51                      Drama
# 9190685             95  Action,Adventure,Thriller
# 9190724             84                   Thriller
# 9190769             92              Drama,History
# 9190853            123                      Drama
#
# [136802 rows x 9 columns]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34791       True
# 61091       True
# 67637       True
# 77931      False
# 86768       True
#            ...
# 9190676     True
# 9190685     True
# 9190724    False
# 9190769     True
# 9190853    False
# Name: tconst, Length: 136802, dtype: bool

# %%
#filter basics on the "keepers"
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34791    tt0035423     movie
# 61091    tt0062336     movie
# 67637    tt0069049     movie
# 86768    tt0088751     movie
# 92733    tt0094859     movie
# ...            ...       ...
# 9190140  tt9914942     movie
# 9190536  tt9915872     movie
# 9190676  tt9916170     movie
# 9190685  tt9916190     movie
# 9190769  tt9916362     movie
#
#                                               primaryTitle  \
# 34791                                       Kate & Leopold
# 61091    The Tango of the Widower and Its Distorting Mi...
# 67637                           The Other Side of the Wind
# 86768                                    The Naked Monster
# 92733                                           Chief Zabu
# ...                                                    ...
# 9190140                             Life Without Sara Amat
# 9190536                               The Last White Witch
# 9190676                                      The Rehearsal
# 9190685                                          Safeguard
# 9190769                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34791                               Kate & Leopold       0       2001     NaN
# 61091    El Tango del Viudo y Su Espejo Deformante       0       2020     NaN
# 67637                   The Other Side of the Wind       0       2018     NaN
# 86768                            The Naked Monster       0       2005     NaN
# 92733                                   Chief Zabu       0       2016     NaN
# ...                                            ...     ...        ...     ...
# 9190140                 La vida sense la Sara Amat       0       2019     NaN
# 9190536                  My Girlfriend is a Wizard       0       2019     NaN
# 9190676                                   O Ensaio       0       2019     NaN
# 9190685                                  Safeguard       0       2020     NaN
# 9190769                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34791              118     Comedy,Fantasy,Romance
# 61091               70                      Drama
# 67637              122                      Drama
# 86768              100       Comedy,Horror,Sci-Fi
# 92733               74                     Comedy
# ...                ...                        ...
# 9190140             74                      Drama
# 9190536             97       Comedy,Drama,Fantasy
# 9190676             51                      Drama
# 9190685             95  Action,Adventure,Thriller
# 9190769             92              Drama,History
#
# [79648 rows x 9 columns]

# %%
# show summary of how many movies remain and feature datatypes 
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79648 entries, 34791 to 9190769
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          79648 non-null  object
#  1   titleType       79648 non-null  object
#  2   primaryTitle    79648 non-null  object
#  3   originalTitle   79648 non-null  object
#  4   isAdult         79648 non-null  object
#  5   startYear       79648 non-null  Int64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  79648 non-null  object
#  8   genres          79648 non-null  object
# dtypes: Int64(1), object(8)
# memory usage: 6.2+ MB

# %%
# show summary of how many movies remain and feature datatypes 
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1345465 entries, 5 to 33038403
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1345465 non-null  object
#  1   ordering         1345465 non-null  int64
#  2   title            1345465 non-null  object
#  3   region           1345465 non-null  object
#  4   language         3694 non-null     object
#  5   types            963735 non-null   object
#  6   attributes       44834 non-null    object
#  7   isOriginalTitle  1344090 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 92.4+ MB

# %%
# show summary of how many movies remain and feature datatypes 
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258682 entries, 0 to 1258681
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1258682 non-null  object
#  1   averageRating  1258682 non-null  float64
#  2   numVotes       1258682 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.8+ MB

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1907
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1707
# 3  tt0000004            5.6       168
# 4  tt0000005            6.2      2520
