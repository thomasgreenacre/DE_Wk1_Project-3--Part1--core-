# %%
#imports
import pandas as pd
import numpy as np

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0094859     movie                                         Chief Zabu
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                                 Chief Zabu        0       2016      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74                  Comedy

# %% [markdown]
# ## Part 2

# %%
#imports
import os, time,json
import tmdbsimple as tmdb 
from tqdm.notebook import tqdm_notebook
import time

FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['.ipynb_checkpoints',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json']

# %%
#get TMBD API credentials
with open('/Users/thoma/.secret/tmdb_api.json') as f:
    api_creds = json.load(f)

api_creds.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#create function to use api creds
tmdb.API_KEY = api_creds['api-key']

# %%
#define years
YEARS_TO_GET = [2000,2001]

# %%
def write_json(new_data, filename): 
    """Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""    
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file) 
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
def get_movie_with_rating(movie_id):
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    # save the .info .releases dictionaries
    movie_info = movie.info()
    releases = movie.releases()
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
            movie_info['certification'] = c['certification']
    return movie_info

# %%
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv('Data/title_basics.csv.gz')

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79648 entries, 0 to 79647
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          79648 non-null  object
#  1   titleType       79648 non-null  object
#  2   primaryTitle    79648 non-null  object
#  3   originalTitle   79648 non-null  object
#  4   isAdult         79648 non-null  int64
#  5   startYear       79648 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  79648 non-null  int64
#  8   genres          79648 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.5+ MB

# %%
get_movie_with_rating('tt0848228')
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 225.297,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.706,
#  'vote_count': 27426,
#  'certification': 'PG-13'}

# %%
get_movie_with_rating('tt0332280')
# Out:
# {'adult': False,
#  'backdrop_path': '/qom1SZSENdmHFNZBXbtJAU0WTlC.jpg',
#  'belongs_to_collection': None,
#  'budget': 29000000,
#  'genres': [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.newline.com/properties/notebookthe.html',
#  'id': 11036,
#  'imdb_id': 'tt0332280',
#  'original_language': 'en',
#  'original_title': 'The Notebook',
#  'overview': "An epic love story centered around an older man who reads aloud to a woman with Alzheimer's. From a faded notebook, the old man's words bring to life the story about a couple who is separated by World War II, and is then passionately reunited, seven years later, after they have taken different paths.",
#  'popularity': 73.78,
#  'poster_path': '/rNzQyW4f8B8cQeg7Dgj3n6eT5k9.jpg',
#  'production_companies': [{'id': 12,
#    'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png',
#    'name': 'New Line Cinema',
#    'origin_country': 'US'},
#   {'id': 1565, 'logo_path': None, 'name': 'Avery Pix', 'origin_country': 'US'},
#   {'id': 2605,
#    'logo_path': None,
#    'name': 'Gran Via Productions',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2004-06-25',
#  'revenue': 115603229,
#  'runtime': 123,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Behind every great love is a great story.',
#  'title': 'The Notebook',
#  'video': False,
#  'vote_average': 7.88,
#  'vote_count': 9764,
#  'certification': 'PG-13'}

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET,desc='YEARS',position=0):
    
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # If it does not exist: create it
    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)
    
    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()
    # saving movie ids to list
    movie_ids = df['tconst'].copy()#.to_list()
    
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    
    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
            
            #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                      desc=f'Movies from {YEAR}',
                                      position=1,
                                      leave=True):
            # Attempt to retrieve then data for the movie id
            try:
                temp = get_movie_with_rating(movie_id)  #This uses your pre-made function
                # Append/extend results to existing file using a pre-made function
                write_json(temp,JSON_FILE)
                # Short 20 ms sleep to prevent overwhelming server
                time.sleep(0.02)

            # If it fails,  make a dict with just the id and None for certification.
            except Exception as e:
                continue

    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/206 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/242 [00:00<?, ?it/s]

# %%
# Open saved file and preview again
df_2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0120454    0.0  /lBKUKP07gLtgXVitepsoCfzbqCi.jpg                   NaN
# 2  tt0151372    0.0                               NaN                   NaN
# 3  tt0154352    0.0                               NaN                   NaN
# 4  tt0168515    0.0                               NaN                   NaN
#
#    budget                                             genres homepage  \
# 0     NaN                                                NaN      NaN
# 1     0.0  [{'id': 99, 'name': 'Documentary'}, {'id': 104...      NaN
# 2     0.0                [{'id': 99, 'name': 'Documentary'}]      NaN
# 3     0.0                [{'id': 99, 'name': 'Documentary'}]      NaN
# 4     0.0  [{'id': 99, 'name': 'Documentary'}, {'id': 104...      NaN
#
#          id original_language              original_title  ... revenue  \
# 0       NaN               NaN                         NaN  ...     NaN
# 1  116569.0                en                       Vinyl  ...     0.0
# 2  150578.0                sv  Ljuset håller mig sällskap  ...     0.0
# 3  110666.0                en              Condo Painting  ...     0.0
# 4   26244.0                en    Phish: Bittersweet Motel  ...     0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    110.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     85.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     86.0                                                 []  Released
# 4     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline                     title  video  \
# 0                                    NaN                       NaN    NaN
# 1  A Camera. A Collection. An Obsession.                     Vinyl    0.0
# 2                                    NaN    Light Keeps Me Company    0.0
# 3                                    NaN            Condo Painting    0.0
# 4                                    NaN  Phish: Bittersweet Motel    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           7.2       18.0           NaN
# 2           8.0        6.0           NaN
# 3           0.0        0.0           NaN
# 4           6.8        5.0           NaN
#
# [5 rows x 26 columns]

# %%
# Open saved file and preview again
df_2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0118154    0.0                               NaN                   NaN
# 2  tt0143861    0.0  /2fTB1wwSFbUlACeIwXNJqi8EdJa.jpg                   NaN
# 3  tt0210777    0.0                               NaN                   NaN
# 4  tt0230234    0.0                               NaN                   NaN
#
#      budget                                             genres  \
# 0       NaN                                                NaN
# 1       0.0                [{'id': 99, 'name': 'Documentary'}]
# 2       0.0  [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# 3  500000.0                [{'id': 99, 'name': 'Documentary'}]
# 4       0.0                [{'id': 99, 'name': 'Documentary'}]
#
#                         homepage        id original_language  \
# 0                            NaN       NaN               NaN
# 1                            NaN  292980.0                en
# 2                            NaN   18984.0                en
# 3  http://www.ericsaperston.com/   66780.0                en
# 4                            NaN  148453.0                en
#
#            original_title  ... revenue  runtime  \
# 0                     NaN  ...     NaN      NaN
# 1             White Hotel  ...     0.0     90.0
# 2                 Scratch  ...     0.0     92.0
# 3             The Journey  ...     0.0     93.0
# 4  A Galaxy Far, Far Away  ...     0.0      0.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'Amharic', 'iso_639_1': 'am'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3                                                 []  Released
# 4                                                 []  Released
#
#                                              tagline                   title  \
# 0                                                NaN                     NaN
# 1                                                NaN             White Hotel
# 2                                                NaN                 Scratch
# 3  Sometimes you take a trip. Sometimes the trip ...             The Journey
# 4                                                NaN  A Galaxy Far, Far Away
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0           0.0        0.0           NaN
# 2    0.0           7.6       25.0           NaN
# 3    0.0           5.2        2.0           NaN
# 4    0.0           5.0        1.0            PG
#
# [5 rows x 26 columns]

# %%
df = pd.concat([df_2000, df_2001])

# %%
## Save current dataframe to file.
df.to_csv("Data/tmdb_results_combined.csv.gz",compression='gzip',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2861 entries, 0 to 1478
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2861 non-null   object
#  1   adult                  2859 non-null   float64
#  2   backdrop_path          1356 non-null   object
#  3   belongs_to_collection  199 non-null    object
#  4   budget                 2859 non-null   float64
#  5   genres                 2859 non-null   object
#  6   homepage               225 non-null    object
#  7   id                     2859 non-null   float64
#  8   original_language      2859 non-null   object
#  9   original_title         2859 non-null   object
#  10  overview               2799 non-null   object
#  11  popularity             2859 non-null   float64
#  12  poster_path            2443 non-null   object
#  13  production_companies   2859 non-null   object
#  14  production_countries   2859 non-null   object
#  15  release_date           2820 non-null   object
#  16  revenue                2859 non-null   float64
#  17  runtime                2859 non-null   float64
#  18  spoken_languages       2859 non-null   object
#  19  status                 2859 non-null   object
#  20  tagline                1106 non-null   object
#  21  title                  2859 non-null   object
#  22  video                  2859 non-null   float64
#  23  vote_average           2859 non-null   float64
#  24  vote_count             2859 non-null   float64
#  25  certification          842 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 603.5+ KB

# %% [markdown]
# ### How many movies had at least some valid financial information (values > 0 for budget OR revenue)? 640 movies

# %%
df.drop_duplicates()
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0120454    0.0  /lBKUKP07gLtgXVitepsoCfzbqCi.jpg
# 2     tt0151372    0.0                               NaN
# 3     tt0154352    0.0                               NaN
# 4     tt0168515    0.0                               NaN
# ...         ...    ...                               ...
# 1474  tt7797670    0.0                               NaN
# 1475  tt7797790    0.0                               NaN
# 1476  tt8665056    0.0                               NaN
# 1477  tt8795764    0.0                               NaN
# 1478  tt9071078    0.0                               NaN
#
#      belongs_to_collection  budget  \
# 0                      NaN     NaN
# 1                      NaN     0.0
# 2                      NaN     0.0
# 3                      NaN     0.0
# 4                      NaN     0.0
# ...                    ...     ...
# 1474                   NaN     0.0
# 1475                   NaN     0.0
# 1476                   NaN     0.0
# 1477                   NaN     0.0
# 1478                   NaN     0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# 2                   [{'id': 99, 'name': 'Documentary'}]
# 3                   [{'id': 99, 'name': 'Documentary'}]
# 4     [{'id': 99, 'name': 'Documentary'}, {'id': 104...
# ...                                                 ...
# 1474                     [{'id': 27, 'name': 'Horror'}]
# 1475                     [{'id': 27, 'name': 'Horror'}]
# 1476                    [{'id': 37, 'name': 'Western'}]
# 1477                     [{'id': 27, 'name': 'Horror'}]
# 1478                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN  116569.0
# 2                                                   NaN  150578.0
# 3                                                   NaN  110666.0
# 4                                                   NaN   26244.0
# ...                                                 ...       ...
# 1474                                                NaN  956214.0
# 1475                                                NaN  956219.0
# 1476  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1477  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1478    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                                       Vinyl  ...
# 2                   sv                  Ljuset håller mig sällskap  ...
# 3                   en                              Condo Painting  ...
# 4                   en                    Phish: Bittersweet Motel  ...
# ...                ...                                         ...  ...
# 1474                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 1475                en         Edmund Kemper Part 3: La mort sévit  ...
# 1476                en                        Guns Along The Bravo  ...
# 1477                en                                   New Breed  ...
# 1478                cn                                        致命密函  ...
#
#      revenue  runtime                                   spoken_languages  \
# 0        NaN      NaN                                                NaN
# 1        0.0    110.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2        0.0     85.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3        0.0     86.0                                                 []
# 4        0.0     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...      ...      ...                                                ...
# 1474     0.0     91.0                                                 []
# 1475     0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1476     0.0     85.0                                                 []
# 1477     0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1478     0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released              A Camera. A Collection. An Obsession.
# 2     Released                                                NaN
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 1474  Released                                                NaN
# 1475  Released                                                NaN
# 1476  Released  Evil came to the Southwest until three blazing...
# 1477  Released                                                NaN
# 1478  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                          Vinyl    0.0           7.2
# 2                         Light Keeps Me Company    0.0           8.0
# 3                                 Condo Painting    0.0           0.0
# 4                       Phish: Bittersweet Motel    0.0           6.8
# ...                                          ...    ...           ...
# 1474  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 1475         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 1476                        Guns Along The Bravo    0.0           0.0
# 1477                                   New Breed    0.0           0.0
# 1478                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 0           NaN           NaN
# 1          18.0           NaN
# 2           6.0           NaN
# 3           0.0           NaN
# 4           5.0           NaN
# ...         ...           ...
# 1474        0.0           NaN
# 1475        0.0           NaN
# 1476        0.0           NaN
# 1477        0.0            NR
# 1478        2.0           NaN
#
# [2860 rows x 26 columns]

# %%
#filter df where revenue or budget is > 0
df_1 = df[(df['budget'] > 0) | (df['revenue'] > 0)]
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 9 to 1459
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                640 non-null    object
#  1   adult                  640 non-null    float64
#  2   backdrop_path          524 non-null    object
#  3   belongs_to_collection  102 non-null    object
#  4   budget                 640 non-null    float64
#  5   genres                 640 non-null    object
#  6   homepage               84 non-null     object
#  7   id                     640 non-null    float64
#  8   original_language      640 non-null    object
#  9   original_title         640 non-null    object
#  10  overview               637 non-null    object
#  11  popularity             640 non-null    float64
#  12  poster_path            615 non-null    object
#  13  production_companies   640 non-null    object
#  14  production_countries   640 non-null    object
#  15  release_date           640 non-null    object
#  16  revenue                640 non-null    float64
#  17  runtime                640 non-null    float64
#  18  spoken_languages       640 non-null    object
#  19  status                 640 non-null    object
#  20  tagline                484 non-null    object
#  21  title                  640 non-null    object
#  22  video                  640 non-null    float64
#  23  vote_average           640 non-null    float64
#  24  vote_count             640 non-null    float64
#  25  certification          429 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 135.0+ KB

# %% [markdown]
# ### How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
#get count of movies for certification category
df_1['certification'].value_counts()
# Out:
# R        227
# PG-13    130
# PG        35
# NR        21
# G         16
# Name: certification, dtype: int64

# %% [markdown]
# ### What is the average revenue per certification category?

# %%
#get average revenue for certification category
df_1.groupby('certification')['revenue'].mean()
# Out:
# certification
# G        1.096618e+08
# NR       7.221697e+06
# PG       1.123378e+08
# PG-13    9.970084e+07
# R        3.334614e+07
# Name: revenue, dtype: float64

# %% [markdown]
# ### What is the average budget per certification category?

# %%
#get average budget for certification category
df_1.groupby('certification')['budget'].mean()
# Out:
# certification
# G        3.799165e+07
# NR       5.100957e+06
# PG       4.497857e+07
# PG-13    4.348391e+07
# R        2.013149e+07
# Name: budget, dtype: float64
