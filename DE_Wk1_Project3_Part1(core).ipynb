# %%
#imports
import pandas as pd
import numpy as np

# %%
#assign data to variables
title_basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
title_akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
title_ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
#read variable to dataframe
basics = pd.read_csv(title_basics_url,sep='\t', low_memory=False)

# %%
#read variable to dataframe
akas = pd.read_csv(title_akas_url,sep='\t', low_memory=False)

# %%
#read variable to dataframe
ratings = pd.read_csv(title_ratings_url,sep='\t', low_memory=False)

# %%
#view basics df
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#view datatypes of basics df
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9149170 entries, 0 to 9149169
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 628.2+ MB

# %%
#replace \n with NaN
basics = basics.replace({'\\N':np.nan})
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics['startYear']  = basics['startYear'].astype('float')

# %%
basics['startYear']  = basics['startYear'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 basics['startYear']  = basics['startYear'].astype('int')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\dtypes\cast.py:1148, in astype_nansafe(arr, dtype, copy, skipna)
#    1145     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#    1147 elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1148     return astype_float_to_int_nansafe(arr, dtype, copy)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\dtypes\cast.py:1193, in astype_float_to_int_nansafe(values, dtype, copy)
#    1189 """
#    1190 astype with a check preventing converting NaN to an meaningless integer value.
#    1191 """
#    1192 if not np.isfinite(values).all():
# -> 1193     raise IntCastingNaNError(
#    1194         "Cannot convert non-finite values (NA or inf) to integer"
#    1195     )
#    1196 return values.astype(dtype, copy=copy)
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
#view datatypes of basics df to confirm startYear changed to float
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9149170 entries, 0 to 9149169
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       float64
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: float64(1), object(8)
# memory usage: 628.2+ MB

# %%
basics.value_counts('startYear')
# Out:
# startYear
# 2021.0    423347
# 2018.0    419624
# 2017.0    416866
# 2019.0    407023
# 2016.0    395747
#            ...
# 1881.0         2
# 1878.0         2
# 1885.0         1
# 1883.0         1
# 1874.0         1
# Length: 150, dtype: int64

# %%
#run value_counts on titleType to see spelling of values 
basics.value_counts('titleType')
# Out:
# titleType
# tvEpisode       6890147
# short            884294
# movie            618534
# video            264219
# tvSeries         229623
# tvMovie          137196
# tvMiniSeries      44710
# tvSpecial         37961
# videoGame         31851
# tvShort           10633
# tvPilot               2
# dtype: int64

# %%
akas = akas.replace({'\\N':np.nan})
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
ratings = ratings.replace({'\\N':np.nan})
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.9       256
# 2  tt0000003            6.5      1702
# 3  tt0000004            5.7       168
# 4  tt0000005            6.2      2517

# %%
#filter basics df where 'runtimeMinutes' does not equal NaN
basics = basics[basics['runtimeMinutes'] != 'NaN'] 
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult  startYear endYear runtimeMinutes                    genres
# 0       0     1894.0     NaN              1         Documentary,Short
# 1       0     1892.0     NaN              5           Animation,Short
# 2       0     1892.0     NaN              4  Animation,Comedy,Romance
# 3       0     1892.0     NaN             12           Animation,Short
# 4       0     1893.0     NaN              1              Comedy,Short

# %%
#filter basics df where 'genres'' does not equal NaN
basics = basics[basics['genres'] != 'NaN'] 
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult  startYear endYear runtimeMinutes                    genres
# 0       0     1894.0     NaN              1         Documentary,Short
# 1       0     1892.0     NaN              5           Animation,Short
# 2       0     1892.0     NaN              4  Animation,Comedy,Romance
# 3       0     1892.0     NaN             12           Animation,Short
# 4       0     1893.0     NaN              1              Comedy,Short

# %%
#filter basics df where 'titleType'' equals 'movie'
basics = basics[basics['titleType'] == 'movie'] 
basics.head()
# Out:
#         tconst titleType                 primaryTitle  \
# 8    tt0000009     movie                   Miss Jerry
# 498  tt0000502     movie                     Bohemios
# 570  tt0000574     movie  The Story of the Kelly Gang
# 587  tt0000591     movie             The Prodigal Son
# 610  tt0000615     movie           Robbery Under Arms
#
#                    originalTitle isAdult  startYear endYear runtimeMinutes  \
# 8                     Miss Jerry       0     1894.0     NaN             45
# 498                     Bohemios       0     1905.0     NaN            100
# 570  The Story of the Kelly Gang       0     1906.0     NaN             70
# 587            L'enfant prodigue       0     1907.0     NaN             90
# 610           Robbery Under Arms       0     1907.0     NaN            NaN
#
#                          genres
# 8                       Romance
# 498                         NaN
# 570  Action,Adventure,Biography
# 587                       Drama
# 610                       Drama

# %%
basics = basics[basics['startYear'] == 2000.0] 
basics.head()
# Out:
#            tconst titleType            primaryTitle           originalTitle  \
# 15174   tt0015414     movie  La tierra de los toros  La tierra de los toros
# 100036  tt0102362     movie                  Istota                  Istota
# 105245  tt0107706     movie                 Nothing                 Nothing
# 110439  tt0113026     movie         The Fantasticks         The Fantasticks
# 110496  tt0113086     movie  Florentino y el diablo  Florentino y el diablo
#
#        isAdult  startYear endYear runtimeMinutes           genres
# 15174        0     2000.0     NaN             60              NaN
# 100036       0     2000.0     NaN             80    Drama,Romance
# 105245       0     2000.0     NaN            NaN              NaN
# 110439       0     2000.0     NaN             86  Musical,Romance
# 110496       0     2000.0     NaN            NaN            Drama

# %%
akas.value_counts('region')
# Out:
# region
# FR    3920723
# JP    3920182
# DE    3903654
# IN    3848159
# ES    3843915
#        ...
# PW          1
# NR          1
# TC          1
# TV          1
# NU          1
# Length: 246, dtype: int64

# %%
akas = akas[akas['region'] == 'US'] 
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
basics1 = basics[basics['genres'].str.contains("Documentary")==True]
basics1.head()
# Out:
#            tconst titleType                                      primaryTitle  \
# 117563  tt0120454     movie                                             Vinyl
# 126851  tt0130458     movie                                             Anikó
# 133250  tt0137210     movie  Siestas & Olas: A Surfing Journey Through Mexico
# 140558  tt0144940     movie                                                Fé
# 146725  tt0151372     movie                        Ljuset håller mig sällskap
#
#                                            originalTitle isAdult  startYear  \
# 117563                                             Vinyl       0     2000.0
# 126851                                             Anikó       0     2000.0
# 133250  Siestas & Olas: A Surfing Journey Through Mexico       0     2000.0
# 140558                                                Fé       0     2000.0
# 146725                        Ljuset håller mig sällskap       0     2000.0
#
#        endYear runtimeMinutes             genres
# 117563     NaN            110        Documentary
# 126851     NaN             70        Documentary
# 133250     NaN             87  Documentary,Sport
# 140558     NaN             91        Documentary
# 146725     NaN             78        Documentary

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 15174      False
# 100036     False
# 105245     False
# 110439      True
# 110496     False
#            ...
# 9071214    False
# 9074223    False
# 9078969     True
# 9093977    False
# 9110678    False
# Name: tconst, Length: 5139, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType                                primaryTitle  \
# 110439   tt0113026     movie                             The Fantasticks
# 110502   tt0113092     movie                               For the Cause
# 113248   tt0115937     movie                                 Consequence
# 113687   tt0116391     movie                                        Gang
# 113913   tt0116628     movie                            The Incorporated
# ...            ...       ...                                         ...
# 8836043  tt9242918     movie  Great White Shark: Truth Behind the Legend
# 8911342  tt9404778     movie                                Split Second
# 8914924  tt9412476     movie                         Contratiempo Mortal
# 8958660  tt9505726     movie                                      Escort
# 9078969  tt9765426     movie                            Hammering It Out
#
#                                       originalTitle isAdult  startYear  \
# 110439                              The Fantasticks       0     2000.0
# 110502                                For the Cause       0     2000.0
# 113248                                  Consequence       0     2000.0
# 113687                                         Gang       0     2000.0
# 113913                             The Incorporated       0     2000.0
# ...                                             ...     ...        ...
# 8836043  Great White Shark: Truth Behind the Legend       0     2000.0
# 8911342                                Split Second       0     2000.0
# 8914924                         Contratiempo Mortal       0     2000.0
# 8958660                            Ya jie de gu shi       0     2000.0
# 9078969                            Hammering It Out       0     2000.0
#
#         endYear runtimeMinutes                  genres
# 110439      NaN             86         Musical,Romance
# 110502      NaN            100  Action,Adventure,Drama
# 113248      NaN             91                   Drama
# 113687      NaN            167      Action,Crime,Drama
# 113913      NaN             86         Action,Thriller
# ...         ...            ...                     ...
# 8836043     NaN             75             Documentary
# 8911342     NaN            NaN                   Drama
# 8914924     NaN             90                  Action
# 8958660     NaN            NaN                   Drama
# 9078969     NaN            NaN                     NaN
#
# [2169 rows x 9 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType      primaryTitle     originalTitle  isAdult  \
# 0  tt0113026     movie   The Fantasticks   The Fantasticks        0
# 1  tt0113092     movie     For the Cause     For the Cause        0
# 2  tt0115937     movie       Consequence       Consequence        0
# 3  tt0116391     movie              Gang              Gang        0
# 4  tt0116628     movie  The Incorporated  The Incorporated        0
#
#    startYear  endYear  runtimeMinutes                  genres
# 0     2000.0      NaN            86.0         Musical,Romance
# 1     2000.0      NaN           100.0  Action,Adventure,Drama
# 2     2000.0      NaN            91.0                   Drama
# 3     2000.0      NaN           167.0      Action,Crime,Drama
# 4     2000.0      NaN            86.0         Action,Thriller

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1905
# 1  tt0000002            5.9       256
# 2  tt0000003            6.5      1702
# 3  tt0000004            5.7       168
# 4  tt0000005            6.2      2517
